# %%
a= 10 #int
b= 3.14 #float
c= "sanika" #string
d= True #boolen
list_1= ["Apple","Banana", "Mango"]
touple_1 = (1,2,3,4)
dic_1 = {"name": "sanika", "age":19, "courage": "engineering"}
set_1 = {1,2,3,4,5,6}
print("int:",a)
print("float:",b)
print("name:",c)
print("check:",d)
print("touple=",touple_1)
print("dictionary=",dic_1)
print("set",set_1)
# Out:
# int: 10
# float: 3.14
# name: sanika
# check: True
# touple= (1, 2, 3, 4)
# dictionary= {'name': 'sanika', 'age': 19, 'courage': 'engineering'}
# set {1, 2, 3, 4, 5, 6}

# %% [markdown]
# Name: SANIKA HUBALE
# Class: FY- B
# Roll No.: 214
