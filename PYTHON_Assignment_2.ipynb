# %%
a= 10
b= 20
c= a+b
print("addition=",c)
# Out:
# addition= 30

# %%
a= 100
name ="Sanika"
print("type:", type(a))
print("type:",type(name))
# Out:
# type: <class 'int'>
# type: <class 'str'>

# %%
a= 10
b= float(a)
print("value=",a)
print("conversion value=",b)
# Out:
# value= 10
# conversion value= 10.0

# %%
a= 1
b= 0
print(a and b)
print(a or b)
print(not a)
# Out:
# 0
# 1
# False
